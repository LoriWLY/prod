# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_sample_pred= pd.read_csv("train_sample_pred.csv")
train_sample_pred
# Out:
#          Unnamed: 0  user_id  product_id  prod_reorder_probability  \
# 0                 0   191790       43765                  0.310838
# 1                 1   184280       21333                  0.433645
# 2                 2   165844       40351                  0.396226
# 3                 3    83517        9366                  0.377985
# 4                 4   199470       45104                  0.427970
# ...             ...      ...         ...                       ...
# 1330790     1330790    10779       38647                  0.388759
# 1330791     1330791    37664       49157                  0.349398
# 1330792     1330792   145284       42230                  0.291892
# 1330793     1330793    63162       37646                  0.564763
# 1330794     1330794   198507       33056                  0.273063
#
#          prod_reorder_times  prod_reorder_ratio  user_average_basket  \
# 0                  1.709611            0.415072            11.769231
# ...

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample_pred["y_pred"][train_sample_pred.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample_pred["y_pred"][train_sample_pred.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by y_pred')
ax.set(xlabel='y_pred')
# plt.xlim(-0.01,1)
plt.show()

# %%
train_data= pd.read_csv("train_data.csv")

# %%
train_data.head()
# Out:
#    Unnamed: 0  user_id  product_id  prod_reorder_probability  \
# 0           0        1         196                  0.582500
# 1           1        1       10258                  0.552962
# 2           2        1       10326                  0.521581
# 3           3        1       12427                  0.529482
# 4           4        1       13032                  0.479782
#
#    prod_reorder_times  prod_reorder_ratio  user_average_basket  up_order_rate  \
# 0            4.473875            0.776480                  5.9            1.0
# 1            3.493716            0.713772                  5.9            0.9
# 2            2.873635            0.652009                  5.9            0.1
# 3            3.857058            0.740735                  5.9            1.0
# 4            2.916796            0.657158                  5.9            0.3
#
#    up_orders_since_last_order  up_order_rate_since_first_order  recorded
# ...

# %%
train_sample=train_data.sample(frac=0.05, random_state=None,axis=0)
train_sample.reset_index(drop=True, inplace=True)
train_sample
# Out:
#         Unnamed: 0  user_id  product_id  prod_reorder_probability  \
# 0         10318161   159672       24964                  0.577161
# 1         11333307   175505        8415                  0.081395
# 2         10329177   159827        5618                  0.303176
# 3         11025537   170709       42803                  0.554816
# 4           709195    11194        7746                  0.135789
# ...            ...      ...         ...                       ...
# 665393     2173098    33818       38944                  0.504470
# 665394     2173520    33824       16953                  0.408185
# 665395     9958017   154107        2314                  0.302652
# 665396    12568467   194698       27903                  0.358656
# 665397     6787889   104760       30391                  0.546321
#
#         prod_reorder_times  prod_reorder_ratio  user_average_basket  \
# 0                 3.126242            0.680127             9.478261
# ...

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample["prod_reorder_probability"][train_sample.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample["prod_reorder_probability"][train_sample.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by prod_reorder_probability')
ax.set(xlabel='prod_reorder_probability')
# plt.xlim(-0.01,1)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample["prod_reorder_times"][train_sample.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample["prod_reorder_times"][train_sample.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by prod_reorder_times')
ax.set(xlabel='prod_reorder_times')
# plt.xlim(-0.01,100)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample["prod_reorder_ratio"][train_sample.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample["prod_reorder_ratio"][train_sample.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by prod_reorder_ratio')
ax.set(xlabel='prod_reorder_ratio')
# plt.xlim(-0.01,1)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample["user_average_basket"][train_sample.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample["user_average_basket"][train_sample.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by user_average_basket')
ax.set(xlabel='user_average_basket')
# plt.xlim(-0.01,1)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample["up_order_rate"][train_sample.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample["up_order_rate"][train_sample.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by up_order_rate')
ax.set(xlabel='up_order_rate')
# plt.xlim(-0.01,1)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample["up_orders_since_last_order"][train_sample.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample["up_orders_since_last_order"][train_sample.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by up_orders_since_last_order')
ax.set(xlabel='up_orders_since_last_order')
# plt.xlim(-0.01,1)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.kdeplot(train_sample["up_order_rate_since_first_order"][train_sample.recorded == 1], color="orange", shade=True)
sns.kdeplot(train_sample["up_order_rate_since_first_order"][train_sample.recorded == 0], color="teal", shade=True)
plt.legend(['reorder', 'non-reorder'])
plt.title('reorder or non-reorder by up_order_rate_since_first_order')
ax.set(xlabel='up_order_rate_since_first_order')
# plt.xlim(-0.01,1)
plt.show()
